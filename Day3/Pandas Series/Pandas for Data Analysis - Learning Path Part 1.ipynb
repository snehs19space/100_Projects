# %% [markdown]
# # TASK #1. GUIDED PROJECT INTRODUCTION

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # TASK #2. DEFINE A PANDAS SERIES

# %%
# Pandas is a data manipulation and analysis tool that is built on Numpy.
# Pandas uses a data structure known as DataFrame (think of it as Microsoft excel in Python). 
# DataFrames empower programmers to store and manipulate data in a tabular fashion (rows and columns).
# Series Vs. DataFrame? Series is considered a single column of a DataFrame.

import pandas as pd

# %%
# Let's define a Python list that contains 5 crypto currencies 
crypto_list = ['BTC', 'XRP', 'LTC', 'ADA', 'ETH']
crypto_list
# Out:
# ['BTC', 'XRP', 'LTC', 'ADA', 'ETH']

# %%
# Let's confirm the Datatype
type(crypto_list)
# Out:
# list

# %%
# Let's create a one dimensional Pandas "series" 
# Let's use Pandas Constructor Method to create a series from a Python list
# Note that series is formed of data and associated index (numeric index has been automatically generated) 
# Check Pandas Documentation for More information: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html#pandas.Series
# Object datatype is used for text data (String)
crypto_series = pd.Series(crypto_list)
crypto_series
# Out:
# 0    BTC
# 1    XRP
# 2    LTC
# 3    ADA
# 4    ETH
# dtype: object

# %%
# Let's confirm the Pandas Series Datatype
type(crypto_series)
# Out:
# pandas.core.series.Series

# %%
# Let's define another Pandas Series that contains numeric values (crypto prices) instead of text data
# Note that we have int64 datatype which means it's integer stored in 64 bits in memory
crypto_prices_series = pd.Series(data = [2000,500,2000,20,50])
crypto_prices_series
# Out:
# 0    2000
# 1     500
# 2    2000
# 3      20
# 4      50
# dtype: int64

# %% [markdown]
# # PRACTICE OPPORTUNITY #1 [OPTIONAL]:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_series = pd.Series(data = ['Tata', 'Nippon', 'Jio'])
my_series
# Out:
# 0      Tata
# 1    Nippon
# 2       Jio
# dtype: object

# %%
type(my_series)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # TASK #3. DEFINE A PANDAS SERIES WITH CUSTOM INDEX

# %%
# Let's define a Python list that contains 5 Crypto currencies
crypto_5list = ['BTC', 'XRP', 'LTC', 'ADA', 'ETH']
crypto_5list
# Out:
# ['BTC', 'XRP', 'LTC', 'ADA', 'ETH']

# %%
# Let's define a python list as shown below. This python list will be used for the Series index:
crypto_labels = ['crypto#1', 'crypto#2', 'crypto#3', 'crypto#4', 'crypto#5']
crypto_labels
# Out:
# ['crypto#1', 'crypto#2', 'crypto#3', 'crypto#4', 'crypto#5']

# %%
# Let's create a one dimensional Pandas "series" 
# Let's use Pandas Constructor Method to create a series from a Python list
# Note that this series is formed of data and associated labels 
crypto_custom_series = pd.Series(data = crypto_5list, index = crypto_labels)

# %%
# Let's view the series
crypto_custom_series
# Out:
# crypto#1    BTC
# crypto#2    XRP
# crypto#3    LTC
# crypto#4    ADA
# crypto#5    ETH
# dtype: object

# %%
# Let's obtain the datatype
type(crypto_custom_series)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # TASK #4. DEFINE A PANDAS SERIES FROM A DICTIONARY

# %%
# A Dictionary consists of a collection of key-value pairs. Each key-value pair maps the key to its corresponding value.
# Keys are unique within a dictionary while values may not be. 
# List elements are accessed by their position in the list, via indexing while Dictionary elements are accessed via keys
# Define a dictionary named "my_dict" using key-value pairs
my_dict = {'Employee ID': 1,  'Employee Name': 'Steve', 'Salary [$]': 2000,  'Years with company': 10}

# %%
# Show the dictionary
my_dict
# Out:
# {'Employee ID': 1,
#  'Employee Name': 'Steve',
#  'Salary [$]': 2000,
#  'Years with company': 10}

# %%
# Confirm the dictionary datatype 
type(my_dict)
# Out:
# dict

# %%
# Let's define a Pandas Series Using the dictionary
employee_series = pd.Series(my_dict)
employee_series
# Out:
# Employee ID               1
# Employee Name         Steve
# Salary [$]             2000
# Years with company       10
# dtype: object

# %% [markdown]
# # PRACTICE OPPORTUNITY #2 [OPTIONAL]:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
stocks_dict = {'Tata' : 1000, 'Apple' : 7000, 'Jio' : 8000}
stocks_dict
# Out:
# {'Tata': 1000, 'Apple': 7000, 'Jio': 8000}

# %%
stock_series = pd.Series(stocks_dict)
stock_series
# Out:
# Tata     1000
# Apple    7000
# Jio      8000
# dtype: int64

# %% [markdown]
# # TASK #5. PANDAS ATTRIBUTES

# %%
# Attributes/Properties: do not use parantheses "()" and are used to get Pandas Series Properties. Ex: my_series.values, my_series.shape
# Methods: use parantheses "()" and might include arguments and they actually alter/change the Pandas Series. Ex: my_series.tail(), my_series.head(), my_series.drop_duplicates()
# Indexers: use square brackets "[]" and are used to access specific elements in a Pandas Series or DataFrame. Ex: my_series.loc[], my_series.iloc[]

# Let's redefine a Pandas Series containing our favourite 5 cryptos 
crypto_series = pd.Series(crypto_5list)
crypto_series
# Out:
# 0    BTC
# 1    XRP
# 2    LTC
# 3    ADA
# 4    ETH
# dtype: object

# %%
# ".Values" attribute is used to return Series as ndarray depending on its dtype
# Check this for more information: https://pandas.pydata.org/docs/reference/api/pandas.Series.values.html#pandas.Series.values
crypto_series.values
# Out:
# array(['BTC', 'XRP', 'LTC', 'ADA', 'ETH'], dtype=object)

# %%
# index is used to return the index (axis labels) of the Series
crypto_series.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# dtype is used to return the datatype of the Series ('O' stands for 'object' datatype)
crypto_series.dtype
# Out:
# dtype('O')

# %%
# Check if all elements are unique or not
crypto_series.is_unique
# Out:
# True

# %%
# Check the shape of the Series
# note that a Series is one dimensional
crypto_series.shape
# Out:
# (5,)

# %% [markdown]
# # TASK #6. PANDAS METHODS

# %%
# Methods have parentheses and they actually alter/change the Pandas Series
# Methods: use parantheses "()" and might include arguments. Ex: my_series.tail(), my_series.head(), my_series.drop_duplicates()

# Let's define another Pandas Series that contains numeric values (crypto prices) instead of text data
# Note that we have int64 datatype which means it contains integer values stored in 64 bits in memory
crypto_prices = pd.Series(data = [400,500,1500,70,20])
crypto_prices
# Out:
# 0     400
# 1     500
# 2    1500
# 3      70
# 4      20
# dtype: int64

# %%
# Let's obtain the sum of all elements in the Pandas Series
crypto_prices.sum()
# Out:
# 2490

# %%
# Let's obtain the multiplication of all elements in the Pandas Series
crypto_prices.product()
# Out:
# 420000000000

# %%
# Let's obtain the average
crypto_prices.mean()
# Out:
# 498.0

# %%
# Let's show the first couple of elements in the Pandas Series
crypto_prices.head(2)
# Out:
# 0    400
# 1    500
# dtype: int64

# %%
# Note that head creates a new dataframe 
new_crypto_prices = crypto_prices.head(3)
new_crypto_prices
# Out:
# 0     400
# 1     500
# 2    1500
# dtype: int64

# %% [markdown]
# # PRACTICE OPPORTUNITY #3 [OPTIONAL]:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Show the last 2 rows in the Pandas Series
crypto_prices.tail(2)
# Out:
# 3    70
# 4    20
# dtype: int64

# %%
# How many bytes does this Pandas Series consume in memory?
crypto_prices.memory_usage()
# Out:
# 168

# %% [markdown]
# # TASK #7. IMPORT CSV DATA (1-D) USING PANDAS

# %%
# Pandas read_csv is used to read a csv file and store data in a DataFrame by default (DataFrames will be covered shortly!)
# Use Squeeze to convert it into a Pandas Series (One-dimensional)
# Notice that no foramtting exists when a Series is plotted
BTC_price_series = pd.read_csv('crypto.csv', squeeze = True)
BTC_price_series
# Out:
# 0         457.334015
# 1         424.440002
# 2         394.795990
# 3         408.903992
# 4         398.821014
#             ...
# 2380    55950.746090
# 2381    57750.199220
# 2382    58917.691410
# 2383    58918.832030
# 2384    59095.808590
# Name: BTC-USD Price, Length: 2385, dtype: float64

# %%
type(BTC_price_series)
# Out:
# pandas.core.series.Series

# %%
BTC_price_series_df = pd.read_csv('crypto.csv', squeeze = False)
BTC_price_series_df
# Out:
#       BTC-USD Price
# 0        457.334015
# 1        424.440002
# 2        394.795990
# 3        408.903992
# 4        398.821014
# ...             ...
# 2380   55950.746090
# 2381   57750.199220
# 2382   58917.691410
# 2383   58918.832030
# 2384   59095.808590
#
# [2385 rows x 1 columns]

# %%
type(BTC_price_series_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Note that when you set Squeeze = False, the data is stored in a DataFrame by default. 
# DataFrame is simply used to store multi dimensional data as compares to Pandas Series that only holds 1-D dataset 
# Note that DataFrames has proper formatting when you attempt to view them as shown below 
# Note that Pandas Series has no formatting
BTC_price_series_nosqueeze = pd.read_csv('crypto.csv')
BTC_price_series_nosqueeze
# Out:
#       BTC-USD Price
# 0        457.334015
# 1        424.440002
# 2        394.795990
# 3        408.903992
# 4        398.821014
# ...             ...
# 2380   55950.746090
# 2381   57750.199220
# 2382   58917.691410
# 2383   58918.832030
# 2384   59095.808590
#
# [2385 rows x 1 columns]

# %% [markdown]
# # TASK #8. PANDAS BUILT-IN FUNCTIONS

# %%
# Pandas works great with pre-existing python functions 
# You don't have to play with pandas methods and directly leverage Python functions
# Check Python built-in functions here: https://docs.python.org/3/library/functions.html
BTC_series = pd.read_csv('crypto.csv', squeeze = True)
BTC_series
# Out:
# 0         457.334015
# 1         424.440002
# 2         394.795990
# 3         408.903992
# 4         398.821014
#             ...
# 2380    55950.746090
# 2381    57750.199220
# 2382    58917.691410
# 2383    58918.832030
# 2384    59095.808590
# Name: BTC-USD Price, Length: 2385, dtype: float64

# %%
# Obtain the Data Type of the Pandas Series
type(BTC_series)
# Out:
# pandas.core.series.Series

# %%
# Obtain the length of the Pandas Series
len(BTC_series)
# Out:
# 2385

# %%
# Obtain the maximum value of the Pandas Series
max(BTC_series)
# Out:
# 61243.08594

# %%
# Obtain the minimum value of the Pandas Series
min(BTC_series)
# Out:
# 178.1029968

# %% [markdown]
# # PRACTICE OPPORTUNITY #4 [OPTIONAL]:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Given the Pandas Series shown below, convert all positive values to negative using python built-in functions
# my_series = pd.Series(data = [-10, 100, -30, 50, 100])
my_series = pd.Series(data = [-10, 100, -30, 50, 100])
my_series
# Out:
# 0    -10
# 1    100
# 2    -30
# 3     50
# 4    100
# dtype: int64

# %%
-1 * abs(my_series)
# Out:
# 0    -10
# 1   -100
# 2    -30
# 3    -50
# 4   -100
# dtype: int64

# %%
# Obtain only unique values (i.e.: Remove duplicates) using python built-in functions
set(my_series)
# Out:
# {-30, -10, 50, 100}

# %% [markdown]
# # TASK #9. SORTING PANDAS SERIES

# %%
# Let's import CSV data as follows:
BTC_series = pd.read_csv('crypto.csv', squeeze = True)
BTC_series
# Out:
# 0         457.334015
# 1         424.440002
# 2         394.795990
# 3         408.903992
# 4         398.821014
#             ...
# 2380    55950.746090
# 2381    57750.199220
# 2382    58917.691410
# 2383    58918.832030
# 2384    59095.808590
# Name: BTC-USD Price, Length: 2385, dtype: float64

# %%
# You can sort the values in the dataframe as follows
BTC_series.sort_values()
# Out:
# 119       178.102997
# 122       199.259995
# 121       208.097000
# 120       209.843994
# 123       210.339004
#             ...
# 2382    58917.691410
# 2383    58918.832030
# 2384    59095.808590
# 2366    59302.316410
# 2365    61243.085940
# Name: BTC-USD Price, Length: 2385, dtype: float64

# %%
# Let's view Pandas Series again after sorting, Note that nothing changed in memory! you have to make sure that inplace is set to True
BTC_series
# Out:
# 0         457.334015
# 1         424.440002
# 2         394.795990
# 3         408.903992
# 4         398.821014
#             ...
# 2380    55950.746090
# 2381    57750.199220
# 2382    58917.691410
# 2383    58918.832030
# 2384    59095.808590
# Name: BTC-USD Price, Length: 2385, dtype: float64

# %%
# Set inplace = True to ensure that change has taken place in memory 
BTC_series.sort_values(inplace = True)

# %%
# Note that now the change (ordering) took place 
BTC_series
# Out:
# 119       178.102997
# 122       199.259995
# 121       208.097000
# 120       209.843994
# 123       210.339004
#             ...
# 2382    58917.691410
# 2383    58918.832030
# 2384    59095.808590
# 2366    59302.316410
# 2365    61243.085940
# Name: BTC-USD Price, Length: 2385, dtype: float64

# %%
# Notice that the indexes are now changed 
# You can also sort by index (revert back to the original Pandas Series) as follows: 
BTC_series.sort_index(inplace = True)
BTC_series
# Out:
# 0         457.334015
# 1         424.440002
# 2         394.795990
# 3         408.903992
# 4         398.821014
#             ...
# 2380    55950.746090
# 2381    57750.199220
# 2382    58917.691410
# 2383    58918.832030
# 2384    59095.808590
# Name: BTC-USD Price, Length: 2385, dtype: float64

# %%
BTC_series.sort_values(ascending = False, inplace = True)
BTC_series
# Out:
# 2365    61243.085940
# 2366    59302.316410
# 2384    59095.808590
# 2383    58918.832030
# 2382    58917.691410
#             ...
# 123       210.339004
# 120       209.843994
# 121       208.097000
# 122       199.259995
# 119       178.102997
# Name: BTC-USD Price, Length: 2385, dtype: float64

# %% [markdown]
# # TASK #10. PERFORM MATH OPERATIONS ON PANDAS SERIES

# %%
# Let's import CSV data as follows:
BTC_series = pd.read_csv('crypto.csv', squeeze = True)
BTC_series
# Out:
# 0         457.334015
# 1         424.440002
# 2         394.795990
# 3         408.903992
# 4         398.821014
#             ...
# 2380    55950.746090
# 2381    57750.199220
# 2382    58917.691410
# 2383    58918.832030
# 2384    59095.808590
# Name: BTC-USD Price, Length: 2385, dtype: float64

# %%
# Apply Sum Method on Pandas Series
BTC_series.sum()
# Out:
# 15435379.738852698

# %%
# Apply count Method on Pandas Series
BTC_series.count()
# Out:
# 2385

# %%
# Obtain the maximum value
BTC_series.max()
# Out:
# 61243.08594

# %%
# Obtain the minimum value
BTC_series.min()
# Out:
# 178.1029968

# %%
# My favourite: Describe! 
# Describe is used to obtain all statistical information in one place 
BTC_series.describe()
# Out:
# count     2385.000000
# mean      6471.857333
# std       9289.022505
# min        178.102997
# 25%        454.618988
# 50%       4076.632568
# 75%       8864.766602
# max      61243.085940
# Name: BTC-USD Price, dtype: float64

# %% [markdown]
# # PRACTICE OPPORTUNITY #5 [OPTIONAL]:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Obtain the average price of the BTC_series using two different methods
BTC_avg = BTC_series.sum()/BTC_series.count()
BTC_avg
# Out:
# 6471.857332852284

# %%
BTC_series.mean()
# Out:
# 6471.857332852284

# %% [markdown]
# # TASK #11. CHECK IF A GIVEN ELEMENT EXISTS IN A PANDAS SERIES

# %%
# Let's import CSV data as follows:
BTC_price_series = pd.read_csv('crypto.csv', squeeze = True)
BTC_price_series
# Out:
# 0         457.334015
# 1         424.440002
# 2         394.795990
# 3         408.903992
# 4         398.821014
#             ...
# 2380    55950.746090
# 2381    57750.199220
# 2382    58917.691410
# 2383    58918.832030
# 2384    59095.808590
# Name: BTC-USD Price, Length: 2385, dtype: float64

# %%
# Check if a given number exists in a Pandas Series values
# Returns a boolean "True" or "False"
1295.500000 in BTC_price_series.values
# Out:
# False

# %%
# Check if a given number exists in a Pandas Series index
1295 in BTC_price_series.index
# Out:
# True

# %%
# Note that by default 'in' will search in Pandas index and not values
1295 in BTC_price_series
# Out:
# True

# %% [markdown]
# # CAPSTONE FINAL PROJECT

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # CAPSTONE FINAL PROJECT SOLUTION

# %% [markdown]
# # PART A

# %%
# Import key libraries
import pandas as pd
import numpy as np

# %%
# Define a portfolio dictionary containing 3 stocks and 3 crypto
# Using Yahoo Finance, search for the current closing price of the aforementioned list of cryptos and stocks. 
#  Create a Python dictionary that lists the ticker symbol (Keys) and prices (values).
portfolio = {'BTC':  43500,
             'ETH':  3200,
             'ADA':  1,
             'AAPL': 171,
             'TSLA': 1000, 
             'AMZN': 3175}
print(portfolio)
# Out:
# {'BTC': 43500, 'ETH': 3200, 'ADA': 1, 'AAPL': 171, 'TSLA': 1000, 'AMZN': 3175}

# %%
# Create a Pandas Series from a dictionary to show the cryptos/stocks ticker symbols and their corresponding prices.
my_portfolio_series = pd.Series(portfolio)
my_portfolio_series
# Out:
# BTC     43500
# ETH      3200
# ADA         1
# AAPL      171
# TSLA     1000
# AMZN     3175
# dtype: int64

# %%
# Define another Pandas series containing the number of securities 
# Assume that you have the following number of assets in your portfolio: BTC = 3, ETH = 10, ADA = 1000, AMZN = 20, TSLA = 20, AAPL = 5. Create a new Pandas series that contains these number of securities. Use the ticker symbols as the Pandas series labels. 
number_securities = pd.Series(data = [3, 10, 1000, 5, 20, 20],  index = ['BTC', 'ETH', 'ADA', 'AAPL', 'TSLA', 'AMZN'])
number_securities
# Out:
# BTC        3
# ETH       10
# ADA     1000
# AAPL       5
# TSLA      20
# AMZN      20
# dtype: int64

# %%
# Multiply Pandas Series instances
#Multiply the number of securities by the price of each security. Calculate the total value of the portfolio including all securities.
Total_dollar_value = my_portfolio_series.mul(number_securities);
print(Total_dollar_value)
# Out:
# BTC     130500
# ETH      32000
# ADA       1000
# AAPL       855
# TSLA     20000
# AMZN     63500
# dtype: int64

# %%
print('Total portfolio Value = ${}'.format(Total_dollar_value.sum()))
# Out:
# Total portfolio Value = $247855

# %% [markdown]
# # PART B

# %%
# Pandas read_csv is used to read a csv file and store data in a DataFrame by default (DataFrames will be covered shortly!)
# Use Squeeze to convert it into a Pandas Series (One-dimensional)
# Notice that no foramtting exists when a Series is plotted
# Using Pandas, read the csv file into Pandas DataFrame. Check the datatype.
sp500 = pd.read_csv('S&P500_Prices.csv')
sp500
# Out:
#             sp500
# 0     1295.500000
# 1     1289.089966
# 2     1293.670044
# 3     1308.040039
# 4     1314.500000
# ...           ...
# 2154  3327.770020
# 2155  3349.159912
# 2156  3351.280029
# 2157  3360.469971
# 2158  3333.689941
#
# [2159 rows x 1 columns]

# %%
type(sp500)
# Out:
# pandas.core.frame.DataFrame

# %%
# Pandas read_csv is used to read a csv file and store data in a DataFrame by default (DataFrames will be covered shortly!)
# Use Squeeze to convert it into a Pandas Series (One-dimensional)
# Notice that no foramtting exists when a Series is plotted
# Using Pandas, read the csv file into a Pandas Series. Check the datatype.
sp500 = pd.read_csv('S&P500_Prices.csv', squeeze = True)
sp500
# Out:
# 0       1295.500000
# 1       1289.089966
# 2       1293.670044
# 3       1308.040039
# 4       1314.500000
#            ...
# 2154    3327.770020
# 2155    3349.159912
# 2156    3351.280029
# 2157    3360.469971
# 2158    3333.689941
# Name: sp500, Length: 2159, dtype: float64

# %%
# Obtain the Data Type of the Pandas Series
type(sp500)
# Out:
# pandas.core.series.Series

# %%
# Obtain the maximum, minimum and average values of the S&P500.
# Obtain the length of the Pandas Series
len(sp500)
# Out:
# 2159

# %%
# Obtain the maximum value of the Pandas Series
max(sp500)
# Out:
# 3386.149902

# %%
# Obtain the minimum value of the Pandas Series
min(sp500)
# Out:
# 1278.040039

# %%
# Sort the Pandas Series in an ascending and descending order. Enforce the change in memory.
# Set inplace = True to ensure that change has taken place in memory 
sp500.sort_values(inplace = True) 
sp500
# Out:
# 97      1278.040039
# 98      1278.180054
# 99      1285.500000
# 1       1289.089966
# 2       1293.670044
#            ...
# 2038    3373.229980
# 2034    3373.939941
# 2033    3379.449951
# 2035    3380.159912
# 2037    3386.149902
# Name: sp500, Length: 2159, dtype: float64

# %%
# Notice that the indexes are now changed 
# You can also sort by index (revert back to the original Pandas Series) as follows: 
sp500.sort_index(inplace = True)
sp500
# Out:
# 0       1295.500000
# 1       1289.089966
# 2       1293.670044
# 3       1308.040039
# 4       1314.500000
#            ...
# 2154    3327.770020
# 2155    3349.159912
# 2156    3351.280029
# 2157    3360.469971
# 2158    3333.689941
# Name: sp500, Length: 2159, dtype: float64

# %%
sp500.sort_values(ascending = False, inplace = True) 
sp500
# Out:
# 2037    3386.149902
# 2035    3380.159912
# 2033    3379.449951
# 2034    3373.939941
# 2038    3373.229980
#            ...
# 2       1293.670044
# 1       1289.089966
# 99      1285.500000
# 98      1278.180054
# 97      1278.040039
# Name: sp500, Length: 2159, dtype: float64

# %%
# Obtain the average - Solution #1
print(sp500.sum()/sp500.count())

# Obtain the average - Solution #s
print(sp500.mean())
# Out:
# 2218.7495540592868
# 2218.7495540592868

# %%
# Use describe() method to obtain a statistical summary of S&P500. What is standard deviation?
# Describe is used to obtain all statistical information in one place 
sp500.describe()
# Out:
# count    2159.000000
# mean     2218.749554
# std       537.321727
# min      1278.040039
# 25%      1847.984985
# 50%      2106.629883
# 75%      2705.810059
# max      3386.149902
# Name: sp500, dtype: float64

# %%
# With and without rounding the series to the nearest integer, search for the price 3349.
3349 in sp500.values
# Out:
# False

# %%
sp500 = round(sp500)
sp500
# Out:
# 2037    3386.0
# 2035    3380.0
# 2033    3379.0
# 2034    3374.0
# 2038    3373.0
#          ...
# 2       1294.0
# 1       1289.0
# 99      1286.0
# 98      1278.0
# 97      1278.0
# Name: sp500, Length: 2159, dtype: float64

# %%
3349 in sp500.values
# Out:
# True

# %% [markdown]
# # EXCELLENT JOB!
